# %% [markdown]
# ### Creating the Prediction Script:

# %%
# Importing the Libraries

from tensorflow.keras.models import load_model
import numpy as np
import pickle

# Load the model and tokenizer

model = load_model('nextword1.h5')
tokenizer = pickle.load(open('tokenizer1.pkl', 'rb'))

def Predict_Next_Words(model, tokenizer, text):
    """
        In this function we are using the tokenizer and models trained
        and we are creating the sequence of the text entered and then
        using our model to predict and return the the predicted word.
    
    """
    for i in range(3):
        sequence = tokenizer.texts_to_sequences([text])[0]
        sequence = np.array(sequence)
        
        preds = model.predict(sequence)
        pp=(-preds[0]).argsort()[:10]
        #pp=pp[0:5]
        #preds=np.argmax(preds,axis=1)
#         print(preds)
        predicted_word = []
        
        for key, value in tokenizer.word_index.items():
               for word in pp:   
                       if value == word:
                        predicted_word.append(key)
                        break
        
        print(predicted_word)
        return predicted_word

# %%
"""
    We are testing our model and we will run the model
    until the user decides to stop the script.
    While the script is running we try and check if 
    the prediction can be made on the text. If no
    prediction can be made we just continue.

"""

# text1 = "at the dull"
# text2 = "collection of textile"
# text3 = "what a strenuous"
# text4 = "stop the script"

#while(True):
text= 'young woman' 
    #text = input("Enter your line: ")
    
    #if text == "stop the script":
    #    print("Ending The Program.....")
    #    break
    
    #else:
# try:
text = text.split(" ")
text= text[-1]

text = ''.join(text)
Predict_Next_Words(model, tokenizer, text)
            
# except:
        # print('not able to predict')
# Out:
# ['michel', 'stakeout', 'barmaid', 'ludwig', 'idealistic', 'boone', 'armored', 'scrapbook', 'conducting', 'tower']
# ['michel',
#  'stakeout',
#  'barmaid',
#  'ludwig',
#  'idealistic',
#  'boone',
#  'armored',
#  'scrapbook',
#  'conducting',
#  'tower']

# %%
for i in range(3):
        sequence = tokenizer.texts_to_sequences([text])[0]
        sequence = np.array(sequence)
        
        preds1 = model.predict(sequence)
        preds=np.argmax(preds1,axis=1)
#         print(preds)
        predicted_word = ""
        
        for key, value in tokenizer.word_index.items():
            
            if value == preds:
                predicted_word = key
                break
        
        print(predicted_word)
# Out:
# michel
# michel
# michel

# %%
preds
# Out:
# array([1])

# %%
for i in range(3):
        sequence = tokenizer.texts_to_sequences([text])[0]
        sequence = np.array(sequence)
        
        preds = model.predict(sequence)
        pp=(-preds[0]).argsort()[:5]
        #pp=pp[0:5]
        #preds=np.argmax(preds,axis=1)
#         print(preds)
        predicted_word = []
        
        for key, value in tokenizer.word_index.items():
               for word in pp:   
                       if value == word:
                        predicted_word.append(key)
                        break
        
        print(predicted_word)
# Out:
# ['michel', 'stakeout', 'boone', 'motorcycle', 'tower']
# ['michel', 'stakeout', 'boone', 'motorcycle', 'tower']
# ['michel', 'stakeout', 'boone', 'motorcycle', 'tower']

# %%
pp
# Out:
# [8.429658e-05, 8.409122e-05, 8.168712e-05, 8.166742e-05, 8.16668e-05]

# %%
# Out:
# [8.429658e-05,
#  8.409122e-05,
#  8.168712e-05,
#  8.166742e-05,
#  8.16668e-05,
#  8.160547e-05,
#  8.158125e-05,
#  8.156107e-05,
#  8.155463e-05,
#  8.15381e-05,
#  8.1530154e-05,
#  8.1521874e-05,
#  8.151651e-05,
#  8.1509446e-05,
#  8.1507824e-05,
#  8.150777e-05,
